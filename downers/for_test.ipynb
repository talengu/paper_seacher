# %% [markdown]
# ## tip test

# %%
# -*- coding: UTF-8 -*-
from bs4 import BeautifulSoup
import requests

ccf_ai = "https://dblp.uni-trier.de/db/journals/tip/tip27.html"

# from urllib import request
# response = request.urlopen(ccf_ai)
# html = response.read()
# html = html.decode("utf-8")
# print(html)
req = requests.get(url=ccf_ai)
html = req.text
bf = BeautifulSoup(html)
# bf = BeautifulSoup(html)
texts = bf.find_all('div', class_='data')

for text_tag in texts:
    print(text_tag.find_all('span',class_='title')[0].string)
# Out:
# C:\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))
# Farewell Editorial.
# AutoBD: Automated Bi-Level Description for Scalable Fine-Grained Visual Categorization.
# A Fast Gradient Method for Nonnegative Sparse Regression With Self-Dictionary.
# Video Salient Object Detection via Fully Convolutional Networks.
# Knowledge-Based Topic Model for Unsupervised Object Discovery and Localization.
# ...

# %% [markdown]
# ## ijcv test

# %%
from bs4 import BeautifulSoup
import requests
from IPython.core.display import HTML

ccf_ijcv = "https://dblp.uni-trier.de/db/journals/ijcv/ijcv129.html"

# from urllib import request
# response = request.urlopen(ccf_ai)
# html = response.read()
# html = html.decode("utf-8")
# print(html)
req = requests.get(url=ccf_ai)
html = req.text
bf = BeautifulSoup(html)
# bf = BeautifulSoup(html)
texts = bf.find_all('cite', class_='data')
#soup.find_all('div', class_='data')


for text_tag in texts:
    print(text_tag.find_all('span',class_='title')[0].string)
# Out:
# Farewell Editorial.
# AutoBD: Automated Bi-Level Description for Scalable Fine-Grained Visual Categorization.
# A Fast Gradient Method for Nonnegative Sparse Regression With Self-Dictionary.
# Video Salient Object Detection via Fully Convolutional Networks.
# Knowledge-Based Topic Model for Unsupervised Object Discovery and Localization.
# Motion Estimation in Echocardiography Using Sparse Representation and Dictionary Learning.
# Anisotropic-Scale Junction Detection and Matching for Indoor Images.
# PURE-LET Image Deconvolution.
# Hierarchical Recurrent Neural Hashing for Image Retrieval With Hierarchical Convolutional Features.
# Edge Preserving and Multi-Scale Contextual Neural Network for Salient Object Detection.
# Human Motion Segmentation via Robust Kernel Sparse Subspace Clustering.
# Discriminant Analysis on Riemannian Manifold of Gaussian Distributions for Face Recognition With Image Sets.
# Dynamic Video Stitching via Shakiness Removing.
# ...

# %%
HTML(str(texts))
# Out:
# [<cite class="data tts-content" itemprop="headline"><span itemprop="author" itemscope="" itemtype="http://schema.org/Person"><a href="https://dblp.uni-trier.de/pid/24/6475.html" itemprop="url"><span itemprop="name" title="Scott T. Acton">Scott T. Acton</span></a></span>:<br/> <span class="title" itemprop="name">Farewell Editorial.</span> <span itemprop="pagination">8-9</span><meta content="2018" itemprop="datePublished"/><img alt="text to speech" class="tts-button" src="https://dblp.uni-trier.de/img/audio.dark.16x16.png" title="text-to-speech"/></cite>, <cite class="data tts-content" itemprop="headline"><span itemprop="author" itemscope="" itemtype="http://schema.org/Person"><a href="https://dblp.uni-trier.de/pid/167/3478.html" itemprop="url"><span itemprop="name" title="Hantao Yao">Hantao Yao</span></a></span>, <span itemprop="author" itemscope="" itemtype="http://schema.org/Person"><a href="https://dblp.uni-trier.de/pid/52/6186.html" itemprop="url"><span itemprop="name" title="Shil
# ...

# %%
# 主页方法的调试
dblp_tip="https://dblp.uni-trier.de/db/conf/nips/"
req = requests.get(url=dblp_tip)
html = req.text
bf = BeautifulSoup(html)
# bf = BeautifulSoup(html)
texts = bf.find_all('div', class_='data')
# Out:
# C:\Anaconda3\lib\site-packages\bs4\__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file C:\Anaconda3\lib\runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup([your markup])
#
# to this:
#
#  BeautifulSoup([your markup], "lxml")
#
#   markup_type=markup_type))

# %%
from IPython.core.display import HTML
HTML(str(texts[0].a))

tags=bf.find_all('div',class_='data')
for tag in tags:
    spans=tag[5].find_all('span')
    year=spans[-1].string
    url=tag[0].find_all('a')[-1]['href']

# %%
HTML(str(tags[0]))
# Out:
# <div class="data" itemprop="headline"><span itemprop="author" itemscope="" itemtype="http://schema.org/Person"><a href="https://dblp.uni-trier.de/pers/hd/g/Guyon:Isabelle" itemprop="url"><span itemprop="name">Isabelle Guyon</span></a></span>, <span itemprop="author" itemscope="" itemtype="http://schema.org/Person"><a href="https://dblp.uni-trier.de/pers/hd/l/Luxburg:Ulrike_von" itemprop="url"><span itemprop="name">Ulrike von Luxburg</span></a></span>, <span itemprop="author" itemscope="" itemtype="http://schema.org/Person"><a href="https://dblp.uni-trier.de/pers/hd/b/Bengio:Samy" itemprop="url"><span itemprop="name">Samy Bengio</span></a></span>, <span itemprop="author" itemscope="" itemtype="http://schema.org/Person"><a href="https://dblp.uni-trier.de/pers/hd/w/Wallach:Hanna_M=" itemprop="url"><span itemprop="name">Hanna M. Wallach</span></a></span>, <span itemprop="author" itemscope="" itemtype="http://schema.org/Person"><a href="https://dblp.uni-trier.de/pers/hd/f/Fergus:Rob" item
# ...

# %%
tags = bf.find_all('div', class_='data')
for tag in tags:
    spans = tag.find_all('span')
    year=0
    for span in spans:
        if span['itemprop']=='datePublished':
            year = span.string
    print(year)
    url = tag.find_all('a')[-1]['href']
    html_name= url.split('/')[-1]
    second_name=html_name.split('.')[0]
    
    print(url)
# Out:
# 2017
# https://dblp.uni-trier.de/db/conf/nips/nips2017.html
# 2016
# https://dblp.uni-trier.de/db/conf/nips/nips2016.html
# 2016
# https://dblp.uni-trier.de/db/conf/nips/coco2016.html
# 2017
# https://dblp.uni-trier.de/db/conf/nips/idm2016.html
# 2017
# https://dblp.uni-trier.de/db/conf/nips/tsw2016.html
# 2015
# https://dblp.uni-trier.de/db/conf/nips/nips2015.html
# 2016
# https://dblp.uni-trier.de/db/conf/nips/coco2015.html
# 2015
# https://dblp.uni-trier.de/db/conf/nips/fe2015.html
# 2014
# https://dblp.uni-trier.de/db/conf/nips/nips2014.html
# 2014
# https://dblp.uni-trier.de/db/conf/nips/hepml2014.html
# 2016
# https://dblp.uni-trier.de/db/conf/nips/mlini2014.html
# 2013
# https://dblp.uni-trier.de/db/conf/nips/nips2013.html
# 2012
# https://dblp.uni-trier.de/db/conf/nips/nips2012.html
# 2011
# https://dblp.uni-trier.de/db/conf/nips/nips2011.html
# 2012
# https://dblp.uni-trier.de/db/conf/nips/mlini2011.html
# 2010
# https://dblp.uni-trier.de/db/conf/nips/nips2010.html
# 2009
# ...
